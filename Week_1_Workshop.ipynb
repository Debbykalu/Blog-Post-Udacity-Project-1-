# %% [markdown]
# <a href="https://colab.research.google.com/github/Debbykalu/Blog-Post-Udacity-Project-1-/blob/master/Week_1_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Suppose you want to read data from Colab folder in Google drive
# %cd "/content/drive/My Drive/Colab"
# Out:
# /content/drive/My Drive/Colab

# %%
# !ls
# Out:
# World_GDP.csv

# %%
df=pd.read_csv('World_GDP.csv')
print(df)
# Out:
#                     Country Name Country Code  ...          2019          2020
# 0                          Aruba          ABW  ...           NaN           NaN
# 1    Africa Eastern and Southern          AFE  ...  1.010000e+12  9.190000e+11
# 2                    Afghanistan          AFG  ...  1.879945e+10  2.011614e+10
# 3     Africa Western and Central          AFW  ...  7.950000e+11  7.850000e+11
# 4                         Angola          AGO  ...  8.941719e+10  5.837598e+10
# ..                           ...          ...  ...           ...           ...
# 261                       Kosovo          XKX  ...  7.899879e+09  7.716925e+09
# 262                  Yemen, Rep.          YEM  ...           NaN           NaN
# 263                 South Africa          ZAF  ...  3.880000e+11  3.350000e+11
# 264                       Zambia          ZMB  ...  2.330867e+10  1.811063e+10
# 265                     Zimbabwe          ZWE  ...  1.928429e+10  1.805117e+10
#
# [266 rows x 65 columns]

# %%
print(df.to_string())
# Out:
#                                              Country Name Country Code     Indicator Name  Indicator Code          1960          1961          1962          1963          1964          1965          1966          1967          1968          1969          1970          1971          1972          1973          1974          1975          1976          1977          1978          1979          1980          1981          1982          1983          1984          1985          1986          1987          1988          1989          1990          1991          1992          1993          1994          1995          1996          1997          1998          1999          2000          2001          2002          2003          2004          2005          2006          2007          2008          2009          2010          2011          2012          2013          2014          2015          2016          2017          2018          2019          2020
# ...

# %%
print(df.head())
# Out:
#                   Country Name Country Code  ...          2019          2020
# 0                        Aruba          ABW  ...           NaN           NaN
# 1  Africa Eastern and Southern          AFE  ...  1.010000e+12  9.190000e+11
# 2                  Afghanistan          AFG  ...  1.879945e+10  2.011614e+10
# 3   Africa Western and Central          AFW  ...  7.950000e+11  7.850000e+11
# 4                       Angola          AGO  ...  8.941719e+10  5.837598e+10
#
# [5 rows x 65 columns]

# %%
print(df.head(10))
# Out:
#                   Country Name Country Code  ...          2019          2020
# 0                        Aruba          ABW  ...           NaN           NaN
# 1  Africa Eastern and Southern          AFE  ...  1.010000e+12  9.190000e+11
# 2                  Afghanistan          AFG  ...  1.879945e+10  2.011614e+10
# 3   Africa Western and Central          AFW  ...  7.950000e+11  7.850000e+11
# 4                       Angola          AGO  ...  8.941719e+10  5.837598e+10
# 5                      Albania          ALB  ...  1.540024e+10  1.488763e+10
# 6                      Andorra          AND  ...  3.155065e+09           NaN
# 7                   Arab World          ARB  ...  2.760000e+12  2.440000e+12
# 8         United Arab Emirates          ARE  ...  4.170000e+11  3.590000e+11
# 9                    Argentina          ARG  ...  4.520000e+11  3.890000e+11
#
# [10 rows x 65 columns]

# %%
new_df=df.dropna()
print(new_df.to_string())
# Out:
#                                     Country Name Country Code     Indicator Name  Indicator Code          1960          1961          1962          1963          1964          1965          1966          1967          1968          1969          1970          1971          1972          1973          1974          1975          1976          1977          1978          1979          1980          1981          1982          1983          1984          1985          1986          1987          1988          1989          1990          1991          1992          1993          1994          1995          1996          1997          1998          1999          2000          2001          2002          2003          2004          2005          2006          2007          2008          2009          2010          2011          2012          2013          2014          2015          2016          2017          2018          2019          2020
# ...

# %%
#Task 2
w_data=df.loc[(df['Country Name']=='Ireland')|(df['Country Name']=='India')|(df['Country Name']=='Iceland')|(df['Country Name']=='Italy')|(df['Country Name']=='Japan')|(df['Country Name']=='Kenya')|(df['Country Name']=='Zambia')|(df['Country Name']=='Zimbabwe')|(df['Country Name']=='Uganda')|(df['Country Name']=='Turkey'),['2010','2011','2012','2013','2014']]
print(w_data)
# Out:
#              2010          2011          2012          2013          2014
# 109  1.680000e+12  1.820000e+12  1.830000e+12  1.860000e+12  2.040000e+12
# 111  2.220000e+11  2.390000e+11  2.260000e+11  2.380000e+11  2.590000e+11
# 114  1.375116e+10  1.522162e+10  1.475151e+10  1.612506e+10  1.786766e+10
# 116  2.130000e+12  2.290000e+12  2.090000e+12  2.140000e+12  2.160000e+12
# 119  5.760000e+12  6.230000e+12  6.270000e+12  5.210000e+12  4.900000e+12
# 121  4.540559e+10  4.686946e+10  5.639671e+10  6.167143e+10  6.828577e+10
# 244  7.770000e+11  8.390000e+11  8.810000e+11  9.580000e+11  9.390000e+11
# 247  2.667344e+10  2.787173e+10  2.730592e+10  2.891579e+10  3.261240e+10
# 264  2.026556e+10  2.345952e+10  2.550306e+10  2.803724e+10  2.714102e+10
# 265  1.204166e+10  1.410192e+10  1.711485e+10  1.909102e+10  1.949552e+10

# %%
#Task 3
z_score=(w_data-w_data.mean())/w_data.std()
print(z_score)
# Out:
#          2010      2011      2012      2013      2014
# 109  0.336095  0.338390  0.349066  0.482287  0.623684
# 111 -0.465537 -0.465572 -0.466888 -0.490665 -0.494185
# 114 -0.580036 -0.579367 -0.574350 -0.623757 -0.645535
# 116  0.583513  0.577392  0.481327  0.650244  0.699003
# 119  2.579346  2.580941  2.607690  2.491775  2.418801
# 121 -0.562632 -0.563273 -0.553165 -0.596436 -0.613889
# 244 -0.160389 -0.160463 -0.133690 -0.058775 -0.067374
# 247 -0.572931 -0.572934 -0.567963 -0.616084 -0.636280
# 264 -0.576454 -0.575178 -0.568880 -0.616611 -0.639714
# 265 -0.580976 -0.579936 -0.573147 -0.621977 -0.644513

# %%
#Task 4
w_data.plot.line()
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Line graph for GDP Data')
plt.show()
